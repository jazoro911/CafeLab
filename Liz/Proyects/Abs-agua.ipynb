# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Cargar archivos de absorción
file_suffix_A = ['AChMN', 'AGo', 'AMi', 'AOx', 'AIlly']
file_col = ['75', '15','18', '225']

for file_name in file_suffix_A:
    file_path = f'Data/{file_name}.csv'
    try:
        file = pd.read_csv(file_path, engine='python', sep='\t', skiprows=8)
        print(f"{file_name}     CARGADO")
    except FileNotFoundError:
        print(f"No se encontró el archivo {file_name}.csv")
# Out:
# AChMN     CARGADO
# AGo     CARGADO
# AMi     CARGADO
# AOx     CARGADO
# AIlly     CARGADO
