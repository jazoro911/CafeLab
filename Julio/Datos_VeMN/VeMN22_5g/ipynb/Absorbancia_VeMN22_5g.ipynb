# %%
import pandas as pd

# %%
datos = pd.read_csv("Absorbancia_VeMN22_5g_limpio.csv")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nm      441 non-null    float64
#  1   A       364 non-null    float64
# dtypes: float64(2)
# memory usage: 7.0 KB

# %%
datos.head()
# Out:
#       nm   A
# 0  190.0 NaN
# 1  190.5 NaN
# 2  191.0 NaN
# 3  191.5 NaN
# 4  192.0 NaN

# %%
datos.hist(figsize=(5,5), bins=20, edgecolor="black")
# Out:
# array([[<Axes: title={'center': 'nm'}>, <Axes: title={'center': 'A'}>]],
#       dtype=object)

# %%
x=datos["nm"]
y=datos["A"]

# %%
x
# Out:
# 0      190.0
# 1      190.5
# 2      191.0
# 3      191.5
# 4      192.0
#        ...
# 436    408.0
# 437    408.5
# 438    409.0
# 439    409.5
# 440    410.0
# Name: nm, Length: 441, dtype: float64

# %%
y
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 436   NaN
# 437   NaN
# 438   NaN
# 439   NaN
# 440   NaN
# Name: A, Length: 441, dtype: float64

# %%
x.value_counts()
# Out:
# nm
# 410.0    1
# 190.0    1
# 190.5    1
# 191.0    1
# 191.5    1
#         ..
# 196.5    1
# 196.0    1
# 195.5    1
# 195.0    1
# 194.5    1
# Name: count, Length: 441, dtype: int64

# %%
x.values
# Out:
# pandas.core.series.Series

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
type(y.value_counts())
# Out:
# pandas.core.series.Series

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.values
# Out:
# array([  nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan,   nan,   nan, 1.31 , 1.269, 1.231,
#        1.197, 1.169, 1.144, 1.123, 1.105, 1.088, 1.072, 1.056, 1.041,
#        1.026, 1.013, 0.999, 0.985, 0.972, 0.96 , 0.948, 0.936, 0.925,
#        0.913, 0.903, 0.892, 0.882, 0.873, 0.863, 0.855, 0.848, 0.841,
#        0.834, 0.828, 0.822, 0.816, 0.811, 0.805, 0.8  , 0.795, 0.79 ,
#        0.786, 0.782, 0.778, 0.775, 0.772, 0.769, 0.766, 0.763, 0.76 ,
#        0.758, 0.756, 0.754, 0.753, 0.751, 0.749, 0.747, 0.746, 0.744,
#        0.743, 0.741, 0.741, 0.74 , 0.741, 0.742, 0.744, 0.745, 0.747,
#        0.749, 0.751, 0.754, 0.757, 0.76 , 0.764, 0.769, 0.775, 0.781,
#        0.787, 0.793, 0.8  , 0.806, 0.812, 0.818, 0.823, 0.828, 0.834,
#        0.839, 0.846, 0.852, 0.857, 0.862, 0.867, 0.872, 0.879, 0.885,
#        0.891, 0.896, 0.9  , 0.903, 0.905, 0.906, 0.907, 0.907, 0.907,
#        0.907, 0.906, 0.905, 0.905, 0.905, 0.905, 0.905, 0.905, 0.903,
#        0.901, 0.899, 0.897, 0.894, 0.89 , 0.885, 0.881, 0.876, 0.871,
#        0.866, 0.862, 0.856, 0.851, 0.844, 0.838, 0.833, 0.827, 0.822,
#        0.816, 0.809, 0.803, 0.797, 0.791, 0.786, 0.78 , 0.775, 0.77 ,
#        0.764, 0.759, 0.755, 0.751, 0.748, 0.744, 0.741, 0.737, 0.734,
#        0.731, 0.728, 0.725, 0.722, 0.72 , 0.718, 0.716, 0.714, 0.713,
#        0.711, 0.71 , 0.709, 0.708, 0.707, 0.706, 0.705, 0.704, 0.704,
#        0.703, 0.703, 0.703, 0.703, 0.704, 0.704, 0.703, 0.703, 0.702,
#        0.702, 0.703, 0.704, 0.706, 0.708, 0.71 , 0.712, 0.714, 0.715,
#        0.716, 0.716, 0.717, 0.717, 0.717, 0.717, 0.718, 0.719, 0.72 ,
#        0.721, 0.72 , 0.718, 0.716, 0.714, 0.714, 0.713, 0.712, 0.71 ,
#        0.708, 0.706, 0.703, 0.699, 0.696, 0.693, 0.691, 0.687, 0.682,
#        0.677, 0.672, 0.667, 0.661, 0.656, 0.65 , 0.644, 0.638, 0.632,
#        0.626, 0.619, 0.612, 0.605, 0.597, 0.59 , 0.582, 0.574, 0.566,
#        0.557, 0.548, 0.539, 0.532, 0.527, 0.523, 0.519, 0.514, 0.507,
#        0.497, 0.483, 0.467, 0.45 , 0.437, 0.43 , 0.427, 0.423, 0.415,
#        0.403, 0.391, 0.382, 0.377, 0.373, 0.367, 0.359, 0.353, 0.35 ,
#        0.346, 0.34 , 0.331, 0.321, 0.314, 0.307, 0.3  , 0.292, 0.286,
#        0.279, 0.274, 0.271, 0.271, 0.27 , 0.267, 0.261, 0.255, 0.249,
#        0.244, 0.24 , 0.236, 0.229, 0.221, 0.214, 0.209, 0.204, 0.2  ,
#        0.197, 0.196, 0.194, 0.19 , 0.184, 0.18 , 0.177, 0.173, 0.169,
#        0.165, 0.164, 0.158, 0.146, 0.132, 0.128, 0.135, 0.147, 0.153,
#        0.154, 0.152, 0.151, 0.149, 0.147, 0.145, 0.144, 0.142, 0.14 ,
#        0.142, 0.15 , 0.155, 0.153, 0.146, 0.141, 0.142, 0.141, 0.135,
#        0.128, 0.125, 0.129, 0.136, 0.141, 0.14 , 0.133, 0.124, 0.117,
#        0.116, 0.119, 0.122, 0.123, 0.121, 0.121, 0.12 , 0.118, 0.116,
#        0.115, 0.115, 0.115, 0.11 , 0.102, 0.097, 0.097, 0.1  , 0.101,
#        0.1  , 0.098, 0.096, 0.095, 0.092, 0.089, 0.087, 0.087, 0.087,
#        0.086, 0.086, 0.085, 0.082, 0.079, 0.078, 0.078, 0.08 , 0.081,
#        0.082,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan])

# %%
qué hace? y.values.shape

# %%
y.values.shape
# Out:
# (441,)

# %%
import seaborn as sb
sb.scatterplot(x=x,y=y, data=datos, hue="A", palette="coolwarm")
# Out:
# <Axes: xlabel='nm', ylabel='A'>

# %%
from scipy.signal import savgol_filter
import seaborn as sb
import matplotlib.pyplot as plt

# Crear columna suavizada
datos['A_suave'] = savgol_filter(datos['A'], window_length=19, polyorder=3)

# Graficar scatterplot con suavizado y gradiente de color
plt.figure(figsize=(10, 6))
sb.scatterplot(x='nm', y='A_suave', data=datos, hue='A_suave', palette='coolwarm', s=20, edgecolor=None)
plt.title("Absorbancia - Café de Veracruz (Muestra 22.5g - ratio 1:8.88)", fontsize=14)
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Absorbancia")
plt.legend(title='Absorbancia', loc='best')
plt.grid(True)
plt.tight_layout()
plt.show()
